# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
os.chdir(r"F:\sql\sql\Dataset")

# %%
os.listdir()
# Out:
# ['Bank_Account_Details.csv',
#  'Bank_Account_Relationship_Details.csv',
#  'BANK_ACCOUNT_TRANSACTION.csv',
#  'Bank_branch_PL.csv',
#  'Bank_customer.csv',
#  'Bank_customer_export.csv',
#  'BANK_CUSTOMER_MESSAGES.csv',
#  'BANK_INTEREST_RATE.csv',
#  'Bank_Inventory_pricing.csv',
#  'car data (1).csv',
#  'car data.csv',
#  'Car details v3.csv',
#  'Customer.csv',
#  'Customer.xlsx',
#  'cust_seg.csv',
#  'Department_Details.csv',
#  'employee_details.csv',
#  'group_data.xlsx',
#  'homework.xlsx',
#  'Laptop.csv',
#  'LoansData.csv',
#  'London_postal_codes.csv',
#  'Orders.csv',
#  'POS_Q1.csv',
#  'POS_Q2.csv',
#  'POS_Q3.csv',
#  'POS_Q4.csv',
#  'Salesman.csv',
#  'sgdregressor.joblib',
#  'train.csv']

# %%
df=pd.read_csv("LoansData.csv")

# %%
df
# Out:
#       LoanID  Amount.Requested  Amount.Funded.By.Investors  Interest.Rate  \
# 0          1           20000.0                    20000.00           0.09
# 1          2           19200.0                    19200.00           0.12
# 2          3           35000.0                    35000.00           0.22
# 3          4           10000.0                     9975.00           0.10
# 4          5           12000.0                    12000.00           0.12
# ...      ...               ...                         ...            ...
# 2495    2496           30000.0                    29950.00           0.17
# 2496    2497           16000.0                    16000.00           0.14
# 2497    2498           10000.0                    10000.00           0.14
# 2498    2499            6000.0                     6000.00           0.12
# 2499    2500            9000.0                     5242.75           0.14
#
#       Loan.Length        Loan.Purpose  Debt.To.Income.Ratio Home.Ownership  \
# ...

# %%
df.dtypes
# Out:
# LoanID                              int64
# Amount.Requested                  float64
# Amount.Funded.By.Investors        float64
# Interest.Rate                     float64
# Loan.Length                         int64
# Loan.Purpose                       object
# Debt.To.Income.Ratio              float64
# Home.Ownership                     object
# Monthly.Income                    float64
# CIBIL_Score                       float64
# Open.CREDIT.Lines                 float64
# Revolving.CREDIT.Balance          float64
# Inquiries.in.the.Last.6.Months    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# LoanID                            0
# Amount.Requested                  1
# Amount.Funded.By.Investors        1
# Interest.Rate                     2
# Loan.Length                       0
# Loan.Purpose                      0
# Debt.To.Income.Ratio              1
# Home.Ownership                    1
# Monthly.Income                    1
# CIBIL_Score                       2
# Open.CREDIT.Lines                 3
# Revolving.CREDIT.Balance          3
# Inquiries.in.the.Last.6.Months    3
# dtype: int64

# %%
df.shape
# Out:
# (2500, 13)

# %%
df.nunique()
# Out:
# LoanID                            2500
# Amount.Requested                   380
# Amount.Funded.By.Investors         710
# Interest.Rate                       21
# Loan.Length                          2
# Loan.Purpose                        14
# Debt.To.Income.Ratio                36
# Home.Ownership                       5
# Monthly.Income                     632
# CIBIL_Score                         38
# Open.CREDIT.Lines                   29
# Revolving.CREDIT.Balance          2349
# Inquiries.in.the.Last.6.Months      10
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   LoanID                          2500 non-null   int64
#  1   Amount.Requested                2499 non-null   float64
#  2   Amount.Funded.By.Investors      2499 non-null   float64
#  3   Interest.Rate                   2498 non-null   float64
#  4   Loan.Length                     2500 non-null   int64
#  5   Loan.Purpose                    2500 non-null   object
#  6   Debt.To.Income.Ratio            2499 non-null   float64
#  7   Home.Ownership                  2499 non-null   object
#  8   Monthly.Income                  2499 non-null   float64
#  9   CIBIL_Score                     2498 non-null   float64
#  10  Open.CREDIT.Lines               2497 non-null   float64
#  11  Revolving.CREDIT.Balance        2497 non-null   float64
# ...

# %%
df["Loan.Purpose"].nunique()
# Out:
# 14

# %%
df["Loan.Purpose"].value_counts()
# Out:
# debt_consolidation    1307
# credit_card            444
# other                  201
# home_improvement       152
# major_purchase         101
# small_business          87
# car                     50
# wedding                 39
# medical                 30
# moving                  29
# vacation                21
# house                   20
# educational             15
# renewable_energy         4
# Name: Loan.Purpose, dtype: int64

# %%
df["Loan.Purpose"].isnull().sum()
# Out:
# 0

# %%
df["Home.Ownership"].isnull().sum()
# Out:
# 1

# %%
def univariate_cat(x):
    missing=x.isnull().sum()
    unique_cnt=x.nunique()
    unique_cat=(x.unique())
        
    myvalue={"missing" : missing , "unique_cnt": unique_cnt, "unique_cat": unique_cat }
    return(myvalue)

# %%
univariate_cat(df["Home.Ownership"])
# Out:
# {'missing': 1,
#  'unique_cnt': 5,
#  'unique_cat': array(['MORTGAGE', 'RENT', 'OWN', 'OTHER', 'NONE', nan], dtype=object)}

# %%
univariate_cat(df["Loan.Purpose"])
# Out:
# {'missing': 0,
#  'unique_cnt': 14,
#  'unique_cat': array(['debt_consolidation', 'credit_card', 'other', 'moving', 'car',
#         'vacation', 'home_improvement', 'house', 'major_purchase',
#         'educational', 'medical', 'wedding', 'small_business',
#         'renewable_energy'], dtype=object)}

# %%
pd.DataFrame(df["Loan.Purpose"].value_counts(normalize=True)).reset_index()
# Out:
#                  index  Loan.Purpose
# 0   debt_consolidation        0.5228
# 1          credit_card        0.1776
# 2                other        0.0804
# 3     home_improvement        0.0608
# 4       major_purchase        0.0404
# 5       small_business        0.0348
# 6                  car        0.0200
# 7              wedding        0.0156
# 8              medical        0.0120
# 9               moving        0.0116
# 10            vacation        0.0084
# 11               house        0.0080
# 12         educational        0.0060
# 13    renewable_energy        0.0016

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Loan.Purpose', 'Home.Ownership'], dtype='object')

# %%
df.dtypes[df.dtypes!="object"].index
# Out:
# Index(['LoanID', 'Amount.Requested', 'Amount.Funded.By.Investors',
#        'Interest.Rate', 'Loan.Length', 'Debt.To.Income.Ratio',
#        'Monthly.Income', 'CIBIL_Score', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months'],
#       dtype='object')

# %% [markdown]
# ## num

# %%
def univariate_num(x):
    missing=x.isnull().sum()
    min1=round(x.min(), 2)
    max1=round(x.max(), 2)
    mean=round(x.mean(), 2)
    var=round(x.var(), 2)
    std=round(x.std(), 2)
    range1=round(max1-min1, 2)
    q1=round(x.quantile(.25), 2)
    q2=round(x.quantile(.5) , 2)
    q3=round(x.quantile(.75),  2)
    skew=round(x.skew(), 2)
    kurt=round(x.kurt(), 2)
    myvalue={"missing": missing, "min": min1, "max": max1, "mean": mean, "var": var,
            "std": std, "range":range1, "q1": q1, "q2": q2, "q3": q3,
            "skewness": skew, "kurtosis": kurt}
    sns.histplot(x)
    plt.show()
    sns.boxplot(data=df, y=x)
    plt.show()
    return myvalue

# %%
univariate_num(df["Revolving.CREDIT.Balance"])
# Out:
# {'missing': 3,
#  'min': 0.0,
#  'max': 270800.0,
#  'mean': 15223.18,
#  'var': 334195518.85,
#  'std': 18281.02,
#  'range': 270800.0,
#  'q1': 5584.0,
#  'q2': 10948.0,
#  'q3': 18861.0,
#  'skewness': 5.4,
#  'kurtosis': 49.15}

# %%
df.dtypes[df.dtypes!="object"].index
# Out:
# Index(['LoanID', 'Amount.Requested', 'Amount.Funded.By.Investors',
#        'Interest.Rate', 'Loan.Length', 'Debt.To.Income.Ratio',
#        'Monthly.Income', 'CIBIL_Score', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months'],
#       dtype='object')

# %%
df.groupby(["Loan.Purpose"]).agg({"Monthly.Income" : [np.min, np.max, np.mean]})
# Out:
#                    Monthly.Income
#                              amin       amax         mean
# Loan.Purpose
# car                       1200.00   25000.00  5568.632000
# credit_card               1084.00   25000.00  5344.379820
# debt_consolidation        1000.00  102750.00  5724.002173
# educational                588.50    9166.67  4145.705333
# home_improvement          1558.42   25000.00  6789.797500
# house                     1700.00   20833.33  6143.987000
# major_purchase            1000.00   65000.00  6505.119802
# medical                   2000.00   14166.67  5046.561000
# moving                    2000.00   16666.67  5360.492414
# other                      833.33   20833.33  5199.014950
# renewable_energy          1666.67    3416.67  2470.835000
# small_business             866.67   18750.00  5736.500460
# vacation                  3000.00   10000.00  6242.261905
# wedding                   1916.67   22916.67  5723.081282

# %% [markdown]
# ## missing value treatment

# %%
df1=df.fillna(df.median()) 
df1
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8980\1331463849.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1=df.fillna(df.median())
#       LoanID  Amount.Requested  Amount.Funded.By.Investors  Interest.Rate  \
# 0          1           20000.0                    20000.00           0.09
# 1          2           19200.0                    19200.00           0.12
# 2          3           35000.0                    35000.00           0.22
# 3          4           10000.0                     9975.00           0.10
# 4          5           12000.0                    12000.00           0.12
# ...      ...               ...                         ...            ...
# 2495    2496           30000.0                    29950.00           0.17
# 2496    2497           16000.0                    16000.00           0.14
# ...

# %%
df.isnull().sum()
# Out:
# LoanID                            0
# Amount.Requested                  1
# Amount.Funded.By.Investors        1
# Interest.Rate                     2
# Loan.Length                       0
# Loan.Purpose                      0
# Debt.To.Income.Ratio              1
# Home.Ownership                    1
# Monthly.Income                    1
# CIBIL_Score                       2
# Open.CREDIT.Lines                 3
# Revolving.CREDIT.Balance          3
# Inquiries.in.the.Last.6.Months    3
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# LoanID                            0
# Amount.Requested                  0
# Amount.Funded.By.Investors        0
# Interest.Rate                     0
# Loan.Length                       0
# Loan.Purpose                      0
# Debt.To.Income.Ratio              0
# Home.Ownership                    1
# Monthly.Income                    0
# CIBIL_Score                       0
# Open.CREDIT.Lines                 0
# Revolving.CREDIT.Balance          0
# Inquiries.in.the.Last.6.Months    0
# dtype: int64

# %%
df2=df1.fillna(value="rent")

# %% [markdown]
# ## outliers treatment

# %%
f=df2.describe(percentiles=[.01, .02, .03, .04, .05, .25,.5, .75, .9, .95, .96, .97, .98, .99 ]).T
f
# Out:
#                                  count          mean           std      min  \
# LoanID                          2500.0   1250.500000    721.832160     1.00
# Amount.Requested                2500.0  12404.500000   7801.520636  1000.00
# Amount.Funded.By.Investors      2500.0  12001.573236   7745.320754    -0.01
# Interest.Rate                   2500.0      0.130380      0.041273     0.05
# Loan.Length                     2500.0     41.260800      9.930893    36.00
# Debt.To.Income.Ratio            2500.0      0.153852      0.075088     0.00
# Monthly.Income                  2500.0   5688.655748   3962.349122   588.50
# CIBIL_Score                     2500.0    705.900000     35.028571   640.00
# Open.CREDIT.Lines               2500.0     10.071600      4.504863     2.00
# Revolving.CREDIT.Balance        2500.0  15218.054400  18270.638709     0.00
# Inquiries.in.the.Last.6.Months  2500.0      0.905600      1.230811     0.00
#
# ...

# %% [markdown]
# split object and num.

# %%
ob_variable=df2.dtypes[df2.dtypes=="object"].index

# %%
df_obj=df2[ob_variable]

# %%
num_variable=df2.dtypes[df1.dtypes!="object"].index

# %%
df_num=df2[num_variable]

# %%
#oulier capping function -- method-1
def outliers_percentile(x):
    x=x.clip(upper=x.quantile(.99))
    return x

# %%
df_num1=df_num.apply(outliers_percentile)

# %%
z=df_num1.describe(percentiles=[.01, .02, .03, .04, .05, .25,.5, .75, .9, .95, .96, .97, .98, .99 ]).T
z
# Out:
#                                  count          mean           std      min  \
# LoanID                          2500.0   1250.370100    721.610135     1.00
# Amount.Requested                2500.0  12404.500000   7801.520636  1000.00
# Amount.Funded.By.Investors      2500.0  12001.573236   7745.320754    -0.01
# Interest.Rate                   2500.0      0.130296      0.041055     0.05
# Loan.Length                     2500.0     41.260800      9.930893    36.00
# Debt.To.Income.Ratio            2500.0      0.153768      0.074883     0.00
# Monthly.Income                  2500.0   5605.055884   3088.428868   588.50
# CIBIL_Score                     2500.0    705.844000     34.860203   640.00
# Open.CREDIT.Lines               2500.0     10.043200      4.393934     2.00
# Revolving.CREDIT.Balance        2500.0  14764.339000  14757.489385     0.00
# Inquiries.in.the.Last.6.Months  2500.0      0.886400      1.141760     0.00
#
# ...

# %%
df3=pd.concat([df_obj, df_num1], axis=1)
df3
# Out:
#             Loan.Purpose Home.Ownership   LoanID  Amount.Requested  \
# 0     debt_consolidation       MORTGAGE     1.00           20000.0
# 1     debt_consolidation       MORTGAGE     2.00           19200.0
# 2     debt_consolidation       MORTGAGE     3.00           35000.0
# 3     debt_consolidation       MORTGAGE     4.00           10000.0
# 4            credit_card           RENT     5.00           12000.0
# ...                  ...            ...      ...               ...
# 2495  debt_consolidation       MORTGAGE  2475.01           30000.0
# 2496    home_improvement            OWN  2475.01           16000.0
# 2497  debt_consolidation       MORTGAGE  2475.01           10000.0
# 2498      major_purchase           RENT  2475.01            6000.0
# 2499  debt_consolidation           RENT  2475.01            9000.0
#
#       Amount.Funded.By.Investors  Interest.Rate  Loan.Length  \
# 0                       20000.00           0.09           36
# ...

# %%
df3.isnull().sum()
# Out:
# Loan.Purpose                      0
# Home.Ownership                    0
# LoanID                            0
# Amount.Requested                  0
# Amount.Funded.By.Investors        0
# Interest.Rate                     0
# Loan.Length                       0
# Debt.To.Income.Ratio              0
# Monthly.Income                    0
# CIBIL_Score                       0
# Open.CREDIT.Lines                 0
# Revolving.CREDIT.Balance          0
# Inquiries.in.the.Last.6.Months    0
# dtype: int64

# %%
df3.dtypes
# Out:
# Loan.Purpose                       object
# Home.Ownership                     object
# LoanID                            float64
# Amount.Requested                  float64
# Amount.Funded.By.Investors        float64
# Interest.Rate                     float64
# Loan.Length                         int64
# Debt.To.Income.Ratio              float64
# Monthly.Income                    float64
# CIBIL_Score                       float64
# Open.CREDIT.Lines                 float64
# Revolving.CREDIT.Balance          float64
# Inquiries.in.the.Last.6.Months    float64
# dtype: object

# %%
df3.describe(percentiles=[.01, .02, .03, .04, .05, .25,.5, .75, .9, .95, .96, .97, .98, .99 ]).T
# Out:
#                                  count          mean           std      min  \
# LoanID                          2500.0   1250.370100    721.610135     1.00
# Amount.Requested                2500.0  12404.500000   7801.520636  1000.00
# Amount.Funded.By.Investors      2500.0  12001.573236   7745.320754    -0.01
# Interest.Rate                   2500.0      0.130296      0.041055     0.05
# Loan.Length                     2500.0     41.260800      9.930893    36.00
# Debt.To.Income.Ratio            2500.0      0.153768      0.074883     0.00
# Monthly.Income                  2500.0   5605.055884   3088.428868   588.50
# CIBIL_Score                     2500.0    705.844000     34.860203   640.00
# Open.CREDIT.Lines               2500.0     10.043200      4.393934     2.00
# Revolving.CREDIT.Balance        2500.0  14764.339000  14757.489385     0.00
# Inquiries.in.the.Last.6.Months  2500.0      0.886400      1.141760     0.00
#
# ...

# %% [markdown]
# ## dummies created

# %%
df3=pd.get_dummies(data=df3, columns=["Loan.Purpose", "Home.Ownership"] , drop_first=True)

# %% [markdown]
# ## Multicollinearity

# %%
g=df2.corr()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(g, annot=True, cmap="coolwarm")
plt.show()

# %%
df3.columns
# Out:
# Index(['LoanID', 'Amount.Requested', 'Amount.Funded.By.Investors',
#        'Interest.Rate', 'Loan.Length', 'Debt.To.Income.Ratio',
#        'Monthly.Income', 'CIBIL_Score', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Loan.Purpose_credit_card', 'Loan.Purpose_debt_consolidation',
#        'Loan.Purpose_educational', 'Loan.Purpose_home_improvement',
#        'Loan.Purpose_house', 'Loan.Purpose_major_purchase',
#        'Loan.Purpose_medical', 'Loan.Purpose_moving', 'Loan.Purpose_other',
#        'Loan.Purpose_renewable_energy', 'Loan.Purpose_small_business',
#        'Loan.Purpose_vacation', 'Loan.Purpose_wedding', 'Home.Ownership_NONE',
#        'Home.Ownership_OTHER', 'Home.Ownership_OWN', 'Home.Ownership_RENT',
#        'Home.Ownership_rent'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = df3[[ "Amount.Requested",  "Interest.Rate", "Debt.To.Income.Ratio",
         "Monthly.Income", "CIBIL_Score", "Open.CREDIT.Lines", "Revolving.CREDIT.Balance", "Inquiries.in.the.Last.6.Months",
         "Loan.Length",
        'Inquiries.in.the.Last.6.Months', 'Loan.Purpose_credit_card',
       'Loan.Purpose_debt_consolidation', 'Loan.Purpose_educational',
       'Loan.Purpose_home_improvement', 'Loan.Purpose_house',
       'Loan.Purpose_major_purchase', 'Loan.Purpose_medical',
       'Loan.Purpose_moving', 'Loan.Purpose_other',
       'Loan.Purpose_renewable_energy', 'Loan.Purpose_small_business',
       'Loan.Purpose_vacation', 'Loan.Purpose_wedding', 'Home.Ownership_NONE',
       'Home.Ownership_OTHER', 'Home.Ownership_OWN', 'Home.Ownership_RENT',
       'Home.Ownership_rent']]
                         
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
vif_data.sort_values(by=["VIF"], ascending=False)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:195: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#                             feature        VIF
# 7    Inquiries.in.the.Last.6.Months        inf
# 9    Inquiries.in.the.Last.6.Months        inf
# 4                       CIBIL_Score  69.658078
# 8                       Loan.Length  28.120713
# 11  Loan.Purpose_debt_consolidation  26.601246
# 1                     Interest.Rate  16.694831
# 10         Loan.Purpose_credit_card   9.690109
# 5                 Open.CREDIT.Lines   8.388244
# 3                    Monthly.Income   7.505569
# 2              Debt.To.Income.Ratio   7.336929
# 0                  Amount.Requested   6.166762
# 18               Loan.Purpose_other   4.962215
# 13    Loan.Purpose_home_improvement   4.007950
# 15      Loan.Purpose_major_purchase   2.976853
# 6          Revolving.CREDIT.Balance   2.967241
# ...

# %%
df3.drop(columns=["Loan.Length"], inplace=True)

# %% [markdown]
# ## Normal Assumption

# %%
sns.histplot(df3["Interest.Rate"])
plt.show()

# %%
from scipy.stats import shapiro

# %%
shapiro(df3["Interest.Rate"])
# Out:
# ShapiroResult(statistic=0.9767788052558899, pvalue=9.250943694018417e-20)

# %% [markdown]
# transform

# %%
plt.figure(figsize=(8,6))
plt.subplot(221)
sns.histplot(df3["Interest.Rate"])
plt.subplot(222)
sns.histplot(np.sqrt(df3["Interest.Rate"]))
# Out:
# <AxesSubplot:xlabel='Interest.Rate', ylabel='Count'>

# %%
shapiro(np.log1p(df3["Interest.Rate"]))
# Out:
# ShapiroResult(statistic=0.9789263010025024, pvalue=8.700557618459122e-19)

# %%
plt.figure(figsize=(8,6))
plt.subplot(221)
sns.histplot(df3["Interest.Rate"])
plt.subplot(222)
sns.histplot(np.log1p(df3["Interest.Rate"]))
# Out:
# <AxesSubplot:xlabel='Interest.Rate', ylabel='Count'>

# %%
shapiro(np.sqrt(df3["Interest.Rate"]))
# Out:
# ShapiroResult(statistic=0.9815548062324524, pvalue=1.708336910744733e-17)

# %%
df3["shap_data"]=np.sqrt(df3["Interest.Rate"])

# %% [markdown]
# ## Model dev.

# %%
x=df3[["Amount.Requested", "Interest.Rate", "Debt.To.Income.Ratio",
         "Monthly.Income", "CIBIL_Score", "Open.CREDIT.Lines","Revolving.CREDIT.Balance", "Inquiries.in.the.Last.6.Months"]]

y=df3["shap_data"]

# %%
from sklearn.model_selection import train_test_split  # Train test split
from sklearn.linear_model import LinearRegression     # Model development
from sklearn import metrics                            # Model evaluate/

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=.25, 
                                                  random_state=0)

# %%
reg=LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# R^2 : How much % of Variance can be explained  by this model/ variables
print("Train R^2 : ", reg.score(x_train, y_train))
# Out:
# Train R^2 :  0.9922688961972693

# %%
print("Test R^2 : ", reg.score(x_test, y_test))
# Out:
# Test R^2 :  0.9925087166296669

# %%
pred_test=(reg.predict(x_test))
pred_test
# Out:
# array([0.466839  , 0.34406726, 0.29916721, 0.3430142 , 0.33309118,
#        0.41007837, 0.32875276, 0.42354642, 0.39810793, 0.44043313,
#        0.36829209, 0.42335634, 0.31927777, 0.34281082, 0.28030585,
#        0.49398032, 0.46576952, 0.34343589, 0.25461504, 0.38483904,
#        0.32966907, 0.28615445, 0.4930791 , 0.39861874, 0.2941065 ,
#        0.39755561, 0.42227482, 0.34355747, 0.25771035, 0.37082122,
#        0.28825395, 0.3004772 , 0.41337112, 0.30794561, 0.27360299,
#        0.30125606, 0.2958428 , 0.4392112 , 0.35462504, 0.2715695 ,
#        0.31128581, 0.31504801, 0.39708057, 0.34285038, 0.27316464,
#        0.38671982, 0.32935299, 0.34174885, 0.31480614, 0.34056496,
#        0.34266306, 0.43886165, 0.34105495, 0.42571893, 0.28624689,
#        0.27053986, 0.43996172, 0.35935445, 0.38443542, 0.43906496,
#        0.340567  , 0.36877165, 0.3829643 , 0.32928082, 0.42821591,
#        0.30013979, 0.3017871 , 0.32778837, 0.35851056, 0.27339548,
# ...

# %%
pred_train=np.expm1(reg.predict(x_train))
pred_train
# Out:
# array([0.46794691, 0.3313187 , 0.44880754, ..., 0.36879477, 0.31118901,
#        0.57367538])

# %%
y_train=(y_train)
y_train
# Out:
# 444     0.387298
# 161     0.282843
# 1257    0.374166
# 249     0.282843
# 989     0.469042
#           ...
# 1033    0.387298
# 1731    0.346410
# 763     0.316228
# 835     0.264575
# 1653    0.447214
# Name: shap_data, Length: 1875, dtype: float64

# %%
y_test=np.expm1(y_test)

# %%
print("Train MSE", np.mean((pred_train-y_train)**(2)))
print("Train rmse", np.sqrt(np.mean((pred_train-y_train)**(2))))
print("Train MAE",  np.mean(np.abs(pred_train-y_train)))
print("Train MAPE",  np.mean(np.abs((pred_train-y_train)/y_train)))
# Out:
# Train MSE 0.006152656995702239
# Train rmse 0.07843887426335387
# Train MAE 0.07385289514488792
# Train MAPE 0.20238648139886478

# %%
print ("Test MSE" , np.mean((pred_test-y_test)**(2)))
print("Test rmse", np.sqrt(np.mean((pred_test-y_test)**(2))))
print("Test MAE" , np.mean(np.abs(pred_test-y_test)))
print("Test MAPE",  np.mean(np.abs((pred_test-y_test)/y_test)))
# Out:
# Test MSE 0.006246526552191669
# Test rmse 0.07903497043835513
# Test MAE 0.07499813307941129
# Test MAPE 0.16781340716257945

# %% [markdown]
# ### sgd regreasssion

# %% [markdown]
# #### normalizing x variable
# *****
# * whenever we use unsupervised concepts, we always fit on train data
# * we transform on train,test,validation or unseen data
# (dont cheat)
# * this gives the output into array, you can change into dataframe if requires

# %%
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
mn.fit(x_train)
# Out:
# MinMaxScaler()

# %%
x_train_trns=mn.transform(x_train)
x_test_trns=mn.transform(x_test)

# %%
x_train_trns
# Out:
# array([[0.26470588, 0.55555556, 0.51515152, ..., 0.76190476, 0.4270317 ,
#         0.4       ],
#        [0.41176471, 0.16666667, 0.57575758, ..., 0.38095238, 0.18626162,
#         0.        ],
#        [0.18823529, 0.5       , 0.63636364, ..., 0.71428571, 0.0719962 ,
#         0.2       ],
#        ...,
#        [0.48455882, 0.27777778, 0.54545455, ..., 0.61904762, 0.18679187,
#         0.2       ],
#        [0.11764706, 0.11111111, 0.27272727, ..., 0.47619048, 0.04326481,
#         0.        ],
#        [0.32352941, 0.83333333, 0.36363636, ..., 0.38095238, 0.11717643,
#         0.        ]])

# %%
x_train_trns_df=pd.DataFrame(x_train_trns, columns=x_train.columns)
x_train_trns_df.head()
# Out:
#    Amount.Requested  Interest.Rate  Debt.To.Income.Ratio  Monthly.Income  \
# 0          0.264706       0.555556              0.515152        0.426442
# 1          0.411765       0.166667              0.575758        0.215373
# 2          0.188235       0.500000              0.636364        0.196996
# 3          0.205882       0.166667              0.393939        0.160312
# 4          0.464706       0.944444              0.424242        0.187842
#
#    CIBIL_Score  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 0     0.242424           0.761905                  0.427032
# 1     0.606061           0.380952                  0.186262
# 2     0.212121           0.714286                  0.071996
# 3     0.515152           0.285714                  0.073955
# 4     0.121212           0.476190                  0.131796
#
#    Inquiries.in.the.Last.6.Months
# 0                             0.4
# 1                             0.0
# 2                             0.2
# ...

# %%
x_test_trns_df=pd.DataFrame(x_test_trns, columns=x_test.columns)
x_test_trns_df.head()
# Out:
#    Amount.Requested  Interest.Rate  Debt.To.Income.Ratio  Monthly.Income  \
# 0          0.625000       0.888889              0.878788        0.197020
# 1          0.073529       0.388889              0.333333        0.206196
# 2          0.117647       0.222222              0.393939        0.197020
# 3          0.186765       0.388889              0.606061        0.152330
# 4          0.117647       0.333333              0.000000        0.141958
#
#    CIBIL_Score  Open.CREDIT.Lines  Revolving.CREDIT.Balance  \
# 0     0.151515           0.619048                  0.152661
# 1     0.212121           0.333333                  0.107902
# 2     0.606061           0.142857                  0.050602
# 3     0.333333           0.809524                  0.125812
# 4     0.242424           0.142857                  0.046035
#
#    Inquiries.in.the.Last.6.Months
# 0                             0.0
# 1                             0.0
# 2                             0.0
# ...

# %%
from sklearn.linear_model import SGDRegressor

# %%
i

# %%
# help(sgd)

# %%
sgd.fit(x_train_trns, y_train)
# Out:
# SGDRegressor(epsilon=0.01, max_iter=100000000, penalty='l1', random_state=0,
#              tol=1e-07)

# %%
sgd.score(x_train_trns,y_train)
# Out:
# 0.9917010840603634

# %%
sgd.score(x_test_trns, y_test)
# Out:
# 0.05491698330451256

# %%
pred_train=sgd.predict(x_train_trns)
pred_test=sgd.predict(x_test_trns)

# %%
pred_act_train=pd.DataFrame({"act":(y_train)**2, "pred": (pred_train)**(2)})
pred_act_train.head(4)
# Out:
#        act      pred
# 444   0.15  0.147280
# 161   0.08  0.082685
# 1257  0.14  0.137970
# 249   0.08  0.083460

# %%
pred_act_train.head(5).plot(kind="bar")
plt.show()

# %%
print("Train MSE", np.mean((pred_train-y_train)**(2)))
print("Train rmse", np.sqrt(np.mean((pred_train-y_train)**(2))))
print("Train MAE",  np.mean(np.abs(pred_train-y_train)))
print("Train MAPE",  np.mean(np.abs((pred_train-y_train)/y_train)))
# Out:
# Train MSE 2.7716135888590938e-05
# Train rmse 0.005264611656009485
# Train MAE 0.004077288699241605
# Train MAPE 0.012443582962042806

# %%
print ("Test MSE" , np.mean((pred_test-y_test)**(2)))
print("Test rmse", np.sqrt(np.mean((pred_test-y_test)**(2))))
print("Test MAE" , np.mean(np.abs(pred_test-y_test)))
print("Test MAPE",  np.mean(np.abs((pred_test-y_test)/y_test)))
# Out:
# Test MSE 0.006276558871130998
# Test rmse 0.07922473648508399
# Test MAE 0.07492886325131044
# Test MAPE 0.16727755440427539

# %%
from joblib import load, dump

# %%
newdata=pd.DataFrame({ "Amount.Requested":[10000], "Debt.To.Income.Ratio":[.4],
         "Monthly.Income":[2500], "CIBIL_Score":[730],"Revolving.CREDIT.Balance":[7000],
        "Inquiries.in.the.Last.6.Months":[10],
        "Loan.Length":[60],
       'Home.Ownership_NONE':[1]})

# %%
dump(sgd,"sgdregressor.joblib")
# Out:
# ['sgdregressor.joblib']

# %%
mn=MinMaxScaler()
mn.fit(newdata)
newdata_1=mn.transform(newdata)
sd=pd.DataFrame(newdata_1,columns=newdata.columns)

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from joblib import load

# %%
mymodel=load('sgdregressor.joblib')

# %%
(mymodel.predict(sd))**(2)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SGDRegressor was fitted without feature names
#   warnings.warn(
# array([0.06448108])

# %%
# sgd.coef_

# %% [markdown]
# #### OLS Method by stats model

# %%
pd.DataFrame({"Var": x_train.columns, "coef":sgd.coef_})
# Out:
#                               Var      coef
# 0                Amount.Requested  0.004815
# 1                   Interest.Rate  0.235464
# 2            Debt.To.Income.Ratio  0.004277
# 3                  Monthly.Income  0.000796
# 4                     CIBIL_Score -0.014952
# 5               Open.CREDIT.Lines -0.001842
# 6        Revolving.CREDIT.Balance -0.002568
# 7  Inquiries.in.the.Last.6.Months  0.003336

# %%
# if you want in percentage
pd.DataFrame({"Var": x_train.columns, "coef":abs(sgd.coef_)/sum(abs(sgd.coef_))})
# Out:
#                               Var      coef
# 0                Amount.Requested  0.017963
# 1                   Interest.Rate  0.878432
# 2            Debt.To.Income.Ratio  0.015955
# 3                  Monthly.Income  0.002971
# 4                     CIBIL_Score  0.055780
# 5               Open.CREDIT.Lines  0.006873
# 6        Revolving.CREDIT.Balance  0.009581
# 7  Inquiries.in.the.Last.6.Months  0.012445

# %%
import statsmodels.api as sm
X = df3[[]]
y=df3["shap_data"]
x=sm.add_constant(x) 
model = sm.OLS(y,x).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              shap_data   R-squared:                       0.992
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                 4.035e+04
# Date:                Sat, 12 Nov 2022   Prob (F-statistic):               0.00
# Time:                        22:56:53   Log-Likelihood:                 9677.9
# No. Observations:                2500   AIC:                        -1.934e+04
# Df Residuals:                    2491   BIC:                        -1.929e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...
